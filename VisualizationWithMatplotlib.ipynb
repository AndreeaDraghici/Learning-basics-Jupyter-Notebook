# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# use classic style
plt.style.use('classic')
x=np.random.rand(1000)
plt.hist(x)
# Out:
# (array([109., 106.,  90., 107., 119.,  84., 104.,  93.,  91.,  97.]),
#  array([3.18687703e-04, 1.00229466e-01, 2.00140244e-01, 3.00051022e-01,
#         3.99961801e-01, 4.99872579e-01, 5.99783357e-01, 6.99694135e-01,
#         7.99604913e-01, 8.99515692e-01, 9.99426470e-01]),
#  <BarContainer object of 10 artists>)

# %%
# using %matplotlib nitebook for interactuve plots in a notebook
# %matplotlib notebook
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

x=np.linspace(1,30,100)

# plot x and sin function
plt.plot(x,np.sin(x))

# %%
# saving figure to a file

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

fig=plt.figure()
# plot cos and sin function
plt.plot(x,np.cos(x),'-')
plt.plot(x,np.sin(x),'--')

#saving the figure generated above to a file named 'sincos.png'

fig.savefig('../sincos.png')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# annotate sin graph for local minimum and local maximum

fig, ax = plt.subplots()
x=np.linspace(0,20,100)
ax.plot(x,np.sin(x))
ax.axis('equal')

# add arrow for local maximum
ax.annotate('local maximum',xy=(1.71,1),xytext=(10,4),arrowprops=dict(facecolor='black',shrink=0.05))

# add arrow for local minimum
ax.annotate('local minimum',xy=(3.5*np.pi,-1),xytext=(2,-6),arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"));

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# plot an inset axes in another axes by specify the position and sizes w,r,t the main axes
ax1=plt.axes()
ax2=plt.axes([0.65,0.65,0.2,0.2])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# create a figure, add axes with ticks
fig=plt.figure()
ax1=fig.add_axes([0.1,0.5,0.8,0.4],xticklabels=[],ylim=(-1.2,1.2))

ax2=fig.add_axes([0.1,0.1,0.8,0.4],ylim=(-1.2,1.2))

x=np.linspace(0,30,100)

#plot cos and sin functions
ax1.plot(np.cos(x))
ax1.plot(np.sin(x))
